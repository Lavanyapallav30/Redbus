# %%
import pandas as pd

# %%
# !pip install pip-system-certs
# Out:
# ...
#   Using cached pip_system_certs-4.0-py2.py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached pip_system_certs-4.0-py2.py3-none-any.whl (6.1 kB)
# ...

# %%
RB=pd.read_csv(r'/Users/akash/Desktop/webscrap/bus_routes_CHECK.csv')
display(RB)
# Out:
#                                  route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Hyderabad to Vijayawada
# 2                   Hyderabad to Vijayawada
# 3                   Hyderabad to Vijayawada
# 4                   Hyderabad to Vijayawada
# ...                                     ...
# 8361  Jaipur (Rajasthan) to Jammu (j and k)
# 8362  Jaipur (Rajasthan) to Jammu (j and k)
# 8363  Jaipur (Rajasthan) to Jammu (j and k)
# 8364  Jaipur (Rajasthan) to Jammu (j and k)
# 8365  Jaipur (Rajasthan) to Jammu (j and k)
#
#                                              route_link  \
# 0     https://www.redbus.in/bus-tickets/hyderabad-to...
# 1     https://www.redbus.in/bus-tickets/hyderabad-to...
# 2     https://www.redbus.in/bus-tickets/hyderabad-to...
# 3     https://www.redbus.in/bus-tickets/hyderabad-to...
# 4     https://www.redbus.in/bus-tickets/hyderabad-to...
# ...                                                 ...
# ...

# %%
RB['price'] = RB['price'].str.replace('INR', '').astype(float)

# %%
RB
# Out:
#                                  route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Hyderabad to Vijayawada
# 2                   Hyderabad to Vijayawada
# 3                   Hyderabad to Vijayawada
# 4                   Hyderabad to Vijayawada
# ...                                     ...
# 8361  Jaipur (Rajasthan) to Jammu (j and k)
# 8362  Jaipur (Rajasthan) to Jammu (j and k)
# 8363  Jaipur (Rajasthan) to Jammu (j and k)
# 8364  Jaipur (Rajasthan) to Jammu (j and k)
# 8365  Jaipur (Rajasthan) to Jammu (j and k)
#
#                                              route_link  \
# 0     https://www.redbus.in/bus-tickets/hyderabad-to...
# 1     https://www.redbus.in/bus-tickets/hyderabad-to...
# 2     https://www.redbus.in/bus-tickets/hyderabad-to...
# 3     https://www.redbus.in/bus-tickets/hyderabad-to...
# 4     https://www.redbus.in/bus-tickets/hyderabad-to...
# ...                                                 ...
# ...

# %%
print(RB.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8366 entries, 0 to 8365
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   route_name         8366 non-null   object
#  1   route_link         8366 non-null   object
#  2   bus_name           8366 non-null   object
#  3   bus_type           8366 non-null   object
#  4   departing_time     8366 non-null   object
#  5   duration           8366 non-null   object
#  6   reaching_time      8366 non-null   object
#  7   star_rating        8363 non-null   float64
#  8   price              8366 non-null   float64
#  9   seat_availability  4312 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 653.7+ KB
# None

# %%
RB['seat_availability'] = RB['seat_availability'].str.replace(' Seats available', '')
RB['seat_availability'] = RB['seat_availability'].str.replace(' Seat available', '')

# %%
RB['seat_availability'] = RB['seat_availability'].fillna(0)
RB['star_rating'] = RB['star_rating'].astype(float)
RB['star_rating'] = RB['star_rating'].fillna(0)

# %%
RB['seat_availability'] = RB['seat_availability'].astype(int)

# %%
RB['bus_type'].unique()
# Out:
# array(['VENNELA (A.C. SLEEPER)', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)',
#        'DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)',
#        'INDRA(A.C. Seater)', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)',
#        'NIGHT RIDER (SEATER CUM SLEEPER)',
#        'STAR LINER(NON-AC SLEEPER 2+1)', 'Rajdhani (AC Semi Sleeper 2+2)',
#        'GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)', 'eGARUDA',
#        'LAHARI A/C SLEEPER CUM SEATER',
#        'Lahari Non A/C Sleeper Cum Seater', 'Lahari A/C sleeper',
#        'Electric A/C Seater (2+2)', 'A/C Seater / Sleeper (2+1)',
#        'Bharat Benz A/C Seater /Sleeper (2+1)',
#        'Non A/C Seater / Sleeper (2+1)', 'AC Sleeper (2+1)',
#        'A/C Sleeper (2+1)', 'Scania AC Multi Axle Sleeper (2+1)',
#        'Electric A/C Seater/Sleeper (2+1)', 'Electric A/C Sleeper (2+1)',
#        'Electric A/C Semi Sleeper (2+2)', 'A/C Seater/Sleeper (2+1)',
#        'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)',
# ...

# %%
RB['bus_type'] = RB['bus_type'].replace('VENNELA (A.C. SLEEPER)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('INDRA(A.C. Seater)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NIGHT RIDER (SEATER CUM SLEEPER)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('STAR LINER(NON-AC SLEEPER 2+1)', 'Non-AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Rajdhani (AC Semi Sleeper 2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('GARUDA PLUS (VOLVO / BENZ A.C Multi Axle)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('eGARUDA', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('LAHARI A/C SLEEPER CUM SEATER', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Lahari Non A/C Sleeper Cum Seater', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Lahari A/C sleeper', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Electric A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Seater /Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Non A/C Seater / Sleeper (2+1)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('AC Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Scania AC Multi Axle Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Electric A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Electric A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Electric A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('VE A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON AC Seater / Sleeper 2+1', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater/ Sleeper (2+1)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('VE A/C Seater / Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Push Back (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Sleeper (2+1)', 'Non-AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 Multi-Axle A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Airbus (2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi Axle B9R A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater (2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('AC Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Hi-Tech Push Back (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Semi Sleeper / Sleeper (2+1)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo AC Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Hi-Tech (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('ULTRA DELUXE (NON-AC, 2+2 PUSH BACK)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('METRO LUXURY A/C', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle Sleeper A/C (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi Axle B11R AC Seater\Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('SAPTAGIRI EXPRESS', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Express Non AC Seater 2+3', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Express(Non AC Seater)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C Semisleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz NON A/C sleeper (2+1)', 'Non-AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Volvo B11R Multi-Axle Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('VE Executive A/C Sleeper (1+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Mercedes Multi-Axle Semi Sleeper (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle B9R A/c Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C B11R Multi Axle Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle I-Shift A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Sleeper (1+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Scania Multi-Axle AC Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater / Sleeper (2+2)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Semi Sleeper / Sleeper (2+1)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater (2+3)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Non AC Seater (2+3)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Benz A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Deluxe (Non AC Seater 2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater / Sleeper (3+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater / Sleeper (2+2)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Semi Sleeper (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('e-SUP LUXURY (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Sleeper (2+2)', 'Non-AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C (2+2)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Seater (2+2)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Non AC Seater (2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater (2+1)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi Axle Sleeper B11R (2+1)', 'Non-AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Mercedes Benz A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('SWIFT-GARUDA A/C SEATER BUS', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Super Express Non AC Seater Air Bus (2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('AC MULTI AXLE', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Swift Deluxe Non AC Air Bus (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Super Fast Non AC Seater (2+3)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Garuda Premium', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater / Sleeper (3+1)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Low Floor AC Seater 2+2', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('2+1 Air Suspension A/C Seater / Sleeper', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('VE A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C Semi Sleeper (2+2 )', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Super Deluxe Non AC Seater Air Bus (2+2)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Scania AC Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Classy Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 Multi Axle Semi-Sleeper (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Tata A/C Seater Executive Luxury (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Executive (2+3)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('AC Seater (2+3)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater Push Back (2+3)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater (2+3)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('VE A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater Push Back (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Push Back (2+3)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater Push Back (2+3) (2+3)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater Push Back (2+2)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C seater/sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C Seater/Sleeper (2+1)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Non AC Seater 2+2', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Himsuta AC Seater Volvo/Scania 2+2', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Ordinary 3+2 Non AC Seater', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Super Luxury Volvo AC Seater Pushback 2+2', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('HVAC Seater (2+3)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Mercedes Benz Multi-Axle A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo 9600 A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Scania A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Sleeper (2+2)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('VE A/C Sleeper (2+2)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Seater / Sleeper (2+2)', 'AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C Sleeper (2+2)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo Multi-Axle A/C Seater (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Mercedes A/C Semi Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo A/C Sleeper (2+1)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Himmani Deluxe 2+2 Non AC Seater', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater Push Back (2+1)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Volvo AC Seater 2+2', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Volvo AC Seater Pushback 2+2', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('NON AC Seater/ Sleeper (2+1)', 'Non-AC Seater/Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater (2+1)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Non AC Seater (2+1)', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('NON A/C Seater Semi Sleeper (2+1)', 'Non-AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharat Benz A/C Seater (2+1)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Tempo Traveler NON A/C', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater Push Back (2+1)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater Gold Class (2+2)', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Semi Sleeper / Sleeper (2+2)', 'AC Semi-Sleeper')
RB['bus_type'] = RB['bus_type'].replace('AshokLeyland Stile A/C', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Bharath Benz A/C Sleeper (2+2)', 'AC Sleeper')
RB['bus_type'] = RB['bus_type'].replace('Deluxe AC Seater 2+2', 'AC Seater')
RB['bus_type'] = RB['bus_type'].replace('Semi Deluxe Non AC Seater 2+2', 'Non-AC Seater')
RB['bus_type'] = RB['bus_type'].replace('A/C Seater Executive (2+1)', 'AC Seater')
# Out:
# <>:48: SyntaxWarning: invalid escape sequence '\S'
# <>:48: SyntaxWarning: invalid escape sequence '\S'
# /var/folders/fv/kz2c4rvn5ldch9k07l7plnxc0000gn/T/ipykernel_1226/4273345308.py:48: SyntaxWarning: invalid escape sequence '\S'
#   RB['bus_type'] = RB['bus_type'].replace('Volvo Multi Axle B11R AC Seater\Sleeper (2+1)', 'AC Seater/Sleeper')

# %%
RB['bus_type'].unique()
# Out:
# array(['AC Sleeper', 'Non-AC Semi-Sleeper', 'AC Semi-Sleeper',
#        'AC Seater', 'Non-AC Seater/Sleeper', 'Non-AC Sleeper',
#        'AC Seater/Sleeper', 'Non-AC Seater'], dtype=object)

# %%
RB.to_csv('cleaned_RB.csv', index=False)
